# %%
from main import *

# %%
add_moving_avg(table_consolidated, 'Óbitos novos', 7)

# %%
add_moving_avg(table_consolidated, 'Casos confirmados novos', 7)

# %% [markdown]
# ### SITUAÇÃO NO DIA MAIS RECENTE DISPONÍVEL

# %%
table_consolidated[-1:]
# Out:
#            Data  Casos confirmados totais  Óbitos totais  \
# 410  2021-05-03                     71514           1885
#
#      Casos confirmados novos  Óbitos novos  Total de leitos  Leitos ocupados  \
# 410                      664            10            308.0            287.0
#
#      Porcentagem ocupada  Óbitos novos 7d  Casos confirmados novos 7d
# 410            93.181818         6.857143                  278.714286

# %%
PERIODO_DIAS=30

# %% [markdown]
# ### SITUAÇÃO NO PERÍODO

# %%
table_consolidated[-PERIODO_DIAS:]
# Out:
#            Data  Casos confirmados totais  Óbitos totais  \
# 381  2021-04-04                     62630           1543
# 382  2021-04-05                     63531           1573
# 383  2021-04-06                     63926           1605
# 384  2021-04-07                     64308           1621
# 385  2021-04-08                     64549           1642
# 386  2021-04-09                     64947           1652
# 387  2021-04-10                     64947           1652
# 388  2021-04-11                     64947           1652
# 389  2021-04-12                     65725           1668
# 390  2021-04-13                     66123           1695
# 391  2021-04-14                     66404           1705
# 392  2021-04-15                     66726           1728
# 393  2021-04-16                     67072           1741
# 394  2021-04-17                     67072           1741
# 395  2021-04-18                     67072           1741
# ...

# %%
plot_graphic(table_consolidated, PERIODO_DIAS, ['Óbitos novos 7d', 'Óbitos novos'])

# %%
plot_graphic(table_consolidated, PERIODO_DIAS, ['Casos confirmados novos 7d','Casos confirmados novos'])

# %%
plot_graphic(table_consolidated, PERIODO_DIAS, ['Total de leitos','Leitos ocupados'])
