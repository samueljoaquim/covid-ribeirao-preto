# %%
from principal import *

# %%
adicionar_media_movel(consolidada, 7, 'Óbitos novos')

# %%
adicionar_media_movel(consolidada, 7, 'Casos confirmados novos')

# %%
PERIODO_DIAS=29

# %%
consolidada[-PERIODO_DIAS:]
# Out:
#            Data  Casos confirmados totais  Óbitos totais  \
# 384  2021-04-07                     64308           1621
# 385  2021-04-08                     64549           1642
# 386  2021-04-09                     64947           1652
# 387  2021-04-10                     64947           1652
# 388  2021-04-11                     64947           1652
# 389  2021-04-12                     65725           1668
# 390  2021-04-13                     66123           1695
# 391  2021-04-14                     66404           1705
# 392  2021-04-15                     66726           1728
# 393  2021-04-16                     67072           1741
# 394  2021-04-17                     67072           1741
# 395  2021-04-18                     67072           1741
# 396  2021-04-19                     67694           1754
# 397  2021-04-20                     68134           1776
# 398  2021-04-21                     68134           1776
# ...

# %%
plotar_grafico(consolidada, PERIODO_DIAS, ['Óbitos novos M7d', 'Óbitos novos'])

# %%
plotar_grafico(consolidada, PERIODO_DIAS, ['Casos confirmados novos M7d','Casos confirmados novos'])

# %%
plotar_grafico(consolidada, PERIODO_DIAS, ['Total de leitos','Leitos ocupados'])
